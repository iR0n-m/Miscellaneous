# %%
import pandas as pd
import numpy as np

from sklearn.cluster import KMeans
# Calculate silhouette_score
from sklearn.metrics import silhouette_score

import warnings
warnings.filterwarnings("ignore")

from google.colab import drive
drive.mount('/gdrive')
#Change current working directory to gdrive
# %cd /gdrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive

# %%
#Read files
trainfile = r'/gdrive/My Drive/CIS508/Wholesale customers data.csv'
trainData = pd.read_csv(trainfile) #creates a dataframe
print(trainData.shape)
#print(testData.shape)
# Out:
# (440, 8)

# %%
#Extract training and test data
X_train=trainData.iloc[:,2:8].copy()
print(X_train.shape)
X_train.head()
# Out:
# (440, 6)
#    Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0  12669  9656     7561     214              2674        1338
# 1   7057  9810     9568    1762              3293        1776
# 2   6353  8808     7684    2405              3516        7844
# 3  13265  1196     4221    6404               507        1788
# 4  22615  5410     7198    3915              1777        5185

# %%
#K-Means Clustering ========================================================================
#Default Mode
kmeans = KMeans()
kmeans.fit(X_train)
kmeans.labels_
kmeans.cluster_centers_
#Print Silhouette measure
print(silhouette_score(X_train, kmeans.labels_))
# Out:
# 0.3350540474375986

# %%
#Add Cluster Number to each datapoint + save file
df_kmeans=X_train
kmeans_predict_train=kmeans.predict(df_kmeans)
df_kmeans['Cluster Number']=kmeans_predict_train
print(df_kmeans.shape)
df_kmeans.head()
df_kmeans.dtypes

df_kmeans.to_csv(r'/gdrive/My Drive/CIS508/Prob2_resultsDefault.csv')
# Out:
# (440, 7)

# %%
#K-Means Clustering ========================================================================
# K=13

kmeans = KMeans(n_clusters=13, init='random', algorithm='elkan')
kmeans.fit(X_train)
kmeans.labels_
#kmeans.cluster_centers_
print(X_train.shape)
#Print Silhouette measure
print(silhouette_score(X_train, kmeans.labels_))
# Out:
# (440, 7)
# 0.283332969357458

# %%
#Add Cluster Number to each datapoint + save file
df_kmeans=X_train
kmeans_predict_train=kmeans.predict(X_train)

df_kmeans['Cluster Number']=kmeans_predict_train
print(df_kmeans.shape)
df_kmeans.head()
df_kmeans.dtypes

export_csv = df_kmeans.to_csv(r'/gdrive/My Drive/CIS508/Prob2_K=13.csv')
# Out:
# (440, 7)

# %%
#K-Means Clustering ========================================================================
# K=2

kmeans = KMeans(n_clusters=2, init='random', algorithm='elkan')
kmeans.fit(X_train)
kmeans.labels_
print(X_train.shape)
#Print Silhouette measure
print(silhouette_score(X_train, kmeans.labels_))
# Out:
# (440, 7)
# 0.5115333592932941

# %%
#Add Cluster Number to each datapoint + save file
df_kmeans=X_train
kmeans_predict_train=kmeans.predict(X_train)

df_kmeans['Cluster Number']=kmeans_predict_train
print(df_kmeans.shape)
df_kmeans.head()
df_kmeans.dtypes

export_csv = df_kmeans.to_csv(r'/gdrive/My Drive/CIS508/Prob2_K=2.csv')
# Out:
# (440, 7)

# %%
#K-Means Clustering ========================================================================
# K=2

kmeans = KMeans(n_clusters=2, init='random', algorithm='elkan')
kmeans.fit(X_train)
kmeans.labels_
print(X_train.shape)
#Print Silhouette measure
print(silhouette_score(X_train, kmeans.labels_))
# Out:
# (440, 7)
# 0.5115333901825583

# %%
#Add Cluster Number to each datapoint + save file
df_kmeans=X_train
kmeans_predict_train=kmeans.predict(X_train)

df_kmeans['Cluster Number']=kmeans_predict_train
print(df_kmeans.shape)
df_kmeans.head()
df_kmeans.dtypes

export_csv = df_kmeans.to_csv(r'/gdrive/My Drive/CIS508/Prob2_K=2.csv')
# Out:
# (440, 7)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)




Data = pd.read_csv(r'/gdrive/My Drive/CIS508/Prob2_Default.csv')
Data.head()
pivot_table = pd.pivot_table(Data,index=["Cluster Number","Channel","Region"], aggfunc=np.sum)
print(pivot_table)
# Out:
#                                Delicassen  Detergents_Paper    Fresh  Frozen  Grocery    Milk  Unnamed: 0
# Cluster Number Channel Region
# 0              1       1             6392              2525   156781   14677    13239   12089         756
#                        3            37334             11988   786215   98926    81202   55702        3562
#                2       3             3513              3110    80400    1896    10831    7860         422
# 1              1       1            23139             32051   204880   83844   102695   94809        7987
#                        2            15532              6324   111704   74799    65925   29040        5798
#                        3           124709             81324   749348  320029   368899  343589       28955
#                2       1             3617              7059    16403   16879    16969   13253         660
#                        2             1822             10458    22436    2806    22185    9656         890
#                        3            27988             57454   144543   25239   141271  108363        2629
# 2              1       1            29603              5990   368880   68502    66160   53902        4025
#                        2             9824              5920   181794   25193    43523   18695        2837
#                        3            90051             38250  1204044  284822   228464  196545       12070
#                2       1             1553              2568    20782    1759     9212    5921         226
#                        2             7630              7105    60353   13748    19893   13988         969
#                        3            34814             57813   347859   32816   170321  108646        2664
# 3              2       1            10346             65547    25269   15210   134474   82457         879
#                        2             3942             60116    29547    2493   111782   44932         983
#                        3            38537            140593   103140   17709   302070  208937        1135
# 4              2       3            12329            111769   119450   13049   240063  212323         279
# 5              1       3             8550              4948   112151   16745    18148   29627         181
# 6              1       2             5609              1272    32717   60869    13626   16784         325
#                        3            47943               239    36847   36534    20170   43950         183
# 7              1       1            11498             15515    30692   17489    55448   67542        1199
#                        3            11771             29241    39664   14550   103218   66340        2858
#                2       1            18179             72881    31146   12666   171840   92481        2286
#                        2            10147             82116    26170   10224   156340  106049        3050
#                        3            74571            353681   236916   68177   810594  506877        8772

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)




Data = pd.read_csv(r'/gdrive/My Drive/CIS508/Prob2_clusters=13.csv')
Data.head()
pivot_table = pd.pivot_table(Data,index=["Cluster Number","Channel","Region"], aggfunc=np.sum)
print(pivot_table)
# Out:
#                                Delicassen  Detergents_Paper   Fresh  Frozen  Grocery    Milk  Unnamed: 0
# Cluster Number Channel Region
# 0              1       1             6852             17192   18235    4506    50731   40968        1165
#                        3            10777             43928   39884   14892   127112   73488        3258
#                2       1            12800             35297   11483    6562    72410   41722        1345
#                        2             6111             34595   17961    4153    66824   52574        1816
#                        3            57132            186300  155039   49089   412368  284563        6131
# 1              1       2             5609              1272   32717   60869    13626   16784         325
#                        3            47943               239   36847   36534    20170   43950         183
# 2              2       1             7180             57135   26688   12599   130227   69895        1349
#                        2             5369             54819   25272    6774   112753   52261        1554
